# %%
import pandas as pd

# %%
a=pd.read_csv("/content/MobilePriceRange.csv")

# %%
a
# Out:
#       BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0              842               7         2.2          2  2549        19
# 1             1021              53         0.5          3  2631         7
# 2              563              41         0.5          5  2603         9
# 3              615              10         2.5          6  2769        11
# 4             1821              44         1.2          2  1411        15
# ...            ...             ...         ...        ...   ...       ...
# 1995           794               2         0.5          6   668        19
# 1996          1965              39         2.6          4  2032        16
# 1997          1911              36         0.9          8  3057         5
# 1998          1512              46         0.9          5   869        19
# 1999           510              45         2.0          6  3919         2
#
#       DualSim  3G  4G  WiFi  ...  MobileDepth  MobileWeight  TouchScreen  \
# ...

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.head(10)
# Out:
#    BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0           842               7         2.2          2  2549        19
# 1          1021              53         0.5          3  2631         7
# 2           563              41         0.5          5  2603         9
# 3           615              10         2.5          6  2769        11
# 4          1821              44         1.2          2  1411        15
# 5          1859              22         0.5          1  1067        10
# 6          1821              10         1.7          8  3220        18
# 7          1954              24         0.5          4   700         5
# 8          1445              53         0.5          7  1099        20
# 9           509               9         0.6          5   513        12
#
#    DualSim  3G  4G  WiFi  ...  MobileDepth  MobileWeight  TouchScreen  \
# 0        0   0   0     1  ...          0.6           188            0
# ...

# %%
a.tail(4)
# Out:
#       BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 1996          1965              39         2.6          4  2032        16
# 1997          1911              36         0.9          8  3057         5
# 1998          1512              46         0.9          5   869        19
# 1999           510              45         2.0          6  3919         2
#
#       DualSim  3G  4G  WiFi  ...  MobileDepth  MobileWeight  TouchScreen  \
# 1996        1   1   0     1  ...          0.2           187            1
# 1997        1   1   1     0  ...          0.7           108            1
# 1998        0   1   1     1  ...          0.1           145            1
# 1999        1   1   1     1  ...          0.9           168            1
#
#       ScreenHeight  ScreenWidth  FrontCameraPx  RearCameraPX  PxHeight  \
# 1996            11           10              0             3       915
# 1997             9            1              1             3       868
# ...

# %%
a.describe()
# Out:
#        BatteryPower  InternalMemory   ClockSpeed    NoOfCores          RAM  \
# count   2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean    1238.518500       32.046500     1.522250     4.520500  2124.213000
# std      439.418206       18.145715     0.816004     2.287837  1084.732044
# min      501.000000        2.000000     0.500000     1.000000   256.000000
# 25%      851.750000       16.000000     0.700000     3.000000  1207.500000
# 50%     1226.000000       32.000000     1.500000     4.000000  2146.500000
# 75%     1615.250000       48.000000     2.200000     7.000000  3064.500000
# max     1998.000000       64.000000     3.000000     8.000000  3998.000000
#
#           TalkTime      DualSim           3G           4G         WiFi  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     11.011000     0.509500     0.761500     0.521500     0.507000
# std       5.463955     0.500035     0.426273     0.499662     0.500076
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BatteryPower    2000 non-null   int64
#  1   InternalMemory  2000 non-null   int64
#  2   ClockSpeed      2000 non-null   float64
#  3   NoOfCores       2000 non-null   int64
#  4   RAM             2000 non-null   int64
#  5   TalkTime        2000 non-null   int64
#  6   DualSim         2000 non-null   int64
#  7   3G              2000 non-null   int64
#  8   4G              2000 non-null   int64
#  9   WiFi            2000 non-null   int64
#  10  Bluetooth       2000 non-null   int64
#  11  MobileDepth     2000 non-null   float64
#  12  MobileWeight    2000 non-null   int64
#  13  TouchScreen     2000 non-null   int64
#  14  ScreenHeight    2000 non-null   int64
#  15  ScreenWidth     2000 non-null   int64
#  16  FrontCameraPx   2000 non-null   int64
# ...

# %%
a.dtypes
# Out:
# BatteryPower        int64
# InternalMemory      int64
# ClockSpeed        float64
# NoOfCores           int64
# RAM                 int64
# TalkTime            int64
# DualSim             int64
# 3G                  int64
# 4G                  int64
# WiFi                int64
# Bluetooth           int64
# MobileDepth       float64
# MobileWeight        int64
# TouchScreen         int64
# ScreenHeight        int64
# ScreenWidth         int64
# FrontCameraPx       int64
# RearCameraPX        int64
# PxHeight            int64
# PxWeight            int64
# PriceRange         object
# dtype: object

# %%
a[a.dtypes[a.dtypes=='object'].index]
# Out:
#      PriceRange
# 0        Medium
# 1          High
# 2          High
# 3          High
# 4        Medium
# ...         ...
# 1995        Low
# 1996       High
# 1997   VeryHigh
# 1998        Low
# 1999   VeryHigh
#
# [2000 rows x 1 columns]

# %%
b=a[a.dtypes[a.dtypes=='int64'].index]

# %%
b.describe()
# Out:
#        BatteryPower  InternalMemory    NoOfCores          RAM     TalkTime  \
# count   2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean    1238.518500       32.046500     4.520500  2124.213000    11.011000
# std      439.418206       18.145715     2.287837  1084.732044     5.463955
# min      501.000000        2.000000     1.000000   256.000000     2.000000
# 25%      851.750000       16.000000     3.000000  1207.500000     6.000000
# 50%     1226.000000       32.000000     4.000000  2146.500000    11.000000
# 75%     1615.250000       48.000000     7.000000  3064.500000    16.000000
# max     1998.000000       64.000000     8.000000  3998.000000    20.000000
#
#            DualSim           3G           4G         WiFi  Bluetooth  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.0000
# mean      0.509500     0.761500     0.521500     0.507000     0.4950
# std       0.500035     0.426273     0.499662     0.500076     0.5001
# ...

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
a.columns
# Out:
# Index(['BatteryPower', 'InternalMemory', 'ClockSpeed', 'NoOfCores', 'RAM',
#        'TalkTime', 'DualSim', '3G', '4G', 'WiFi', 'Bluetooth', 'MobileDepth',
#        'MobileWeight', 'TouchScreen', 'ScreenHeight', 'ScreenWidth',
#        'FrontCameraPx', 'RearCameraPX', 'PxHeight', 'PxWeight', 'PriceRange'],
#       dtype='object')

# %%
a_sample=a.head(1500)

# %%
a
# Out:
#       BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0              842               7         2.2          2  2549        19
# 1             1021              53         0.5          3  2631         7
# 2              563              41         0.5          5  2603         9
# 3              615              10         2.5          6  2769        11
# 4             1821              44         1.2          2  1411        15
# ...            ...             ...         ...        ...   ...       ...
# 1995           794               2         0.5          6   668        19
# 1996          1965              39         2.6          4  2032        16
# 1997          1911              36         0.9          8  3057         5
# 1998          1512              46         0.9          5   869        19
# 1999           510              45         2.0          6  3919         2
#
#       DualSim  3G  4G  WiFi  ...  MobileDepth  MobileWeight  TouchScreen  \
# ...

# %%
a_sample.head(20)
# Out:
#     BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0            842               7         2.2          2  2549        19
# 1           1021              53         0.5          3  2631         7
# 2            563              41         0.5          5  2603         9
# 3            615              10         2.5          6  2769        11
# 4           1821              44         1.2          2  1411        15
# 5           1859              22         0.5          1  1067        10
# 6           1821              10         1.7          8  3220        18
# 7           1954              24         0.5          4   700         5
# 8           1445              53         0.5          7  1099        20
# 9            509               9         0.6          5   513        12
# 10           769               9         2.9          5  3946         7
# 11          1520              33         2.2          8  3826        13
# ...

# %%
a.dtypes
# Out:
# BatteryPower        int64
# InternalMemory      int64
# ClockSpeed        float64
# NoOfCores           int64
# RAM                 int64
# TalkTime            int64
# DualSim             int64
# 3G                  int64
# 4G                  int64
# WiFi                int64
# Bluetooth           int64
# MobileDepth       float64
# MobileWeight        int64
# TouchScreen         int64
# ScreenHeight        int64
# ScreenWidth         int64
# FrontCameraPx       int64
# RearCameraPX        int64
# PxHeight            int64
# PxWeight            int64
# PriceRange         object
# dtype: object

# %%
a_sample['TouchScreen']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1495    1
# 1496    1
# 1497    0
# 1498    1
# 1499    1
# Name: TouchScreen, Length: 1500, dtype: int64

# %%
a_sample.isnull()
# Out:
#       BatteryPower  InternalMemory  ClockSpeed  NoOfCores    RAM  TalkTime  \
# 0            False           False       False      False  False     False
# 1            False           False       False      False  False     False
# 2            False           False       False      False  False     False
# 3            False           False       False      False  False     False
# 4            False           False       False      False  False     False
# ...            ...             ...         ...        ...    ...       ...
# 1495         False           False       False      False  False     False
# 1496         False           False       False      False  False     False
# 1497         False           False       False      False  False     False
# 1498         False           False       False      False  False     False
# 1499         False           False       False      False  False     False
#
# ...

# %%
type(a.dtypes)
# Out:
# pandas.core.series.Series

# %%
a_sample['TouchScreen'][1400]
# Out:
# np.int64(1)

# %%
a['MobileWeight'][300]
# Out:
# np.int64(189)

# %%
a_sample['TouchScreen'][::-1]
# Out:
# 1499    1
# 1498    1
# 1497    0
# 1496    1
# 1495    1
#        ..
# 4       1
# 3       0
# 2       1
# 1       1
# 0       0
# Name: TouchScreen, Length: 1500, dtype: int64

# %%
a[['3G','4G']]
# Out:
#       3G  4G
# 0      0   0
# 1      1   1
# 2      1   1
# 3      1   0
# 4      1   1
# ...   ..  ..
# 1995   1   1
# 1996   1   0
# 1997   1   1
# 1998   1   1
# 1999   1   1
#
# [2000 rows x 2 columns]

# %%
a.ndim
# Out:
# 2

# %%
a.shape
# Out:
# (2000, 21)

# %%
a_sample['MobileWeight'].unique()
# Out:
# array([188, 136, 145, 131, 141, 164, 139, 187, 174,  93, 182, 177, 159,
#        198, 185, 196, 121, 101,  81, 156, 199, 114, 111, 132, 143,  96,
#        200,  88, 150, 107, 100, 157, 160, 119,  87, 152, 166, 110, 118,
#        162, 127, 109, 102, 104, 148, 180, 128, 134, 144, 168, 155, 165,
#         80, 138, 142,  90, 197, 172, 116,  85, 163, 178, 171, 103,  83,
#        140, 194, 146, 192, 106, 135, 153,  89,  82, 130, 189, 181,  99,
#        184, 195, 108, 133, 179, 147, 137, 190, 176,  84,  97, 124, 183,
#        113,  92,  95, 151, 117,  94, 173, 105, 115,  91, 112, 123, 129,
#        154, 191, 175,  86,  98, 125, 126, 158, 170, 161, 193, 169, 120,
#        149, 186, 122, 167])
